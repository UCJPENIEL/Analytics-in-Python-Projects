# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
print(os.listdir(r"C:\Users\NEW USER\anaconda_projects"))
# Out:
# ['49950659-38ff-46f1-ac3d-78c7b78e6776', 'amir_deals.csv', 'countries-of-the-world.csv', 'db', 'employee_data.xlsx', 'food_consumption.csv', 'mpg.csv', 'netflix_data.csv', 'schools.csv', 'student_alcohol_consumption.csv', 'world_happiness.csv', 'young-people-survey-responses.csv']

# %%
employee = pd.read_excel(r"C:\Users\NEW USER\anaconda_projects\employee_data.xlsx")
print(employee.head(3))
print(employee.isna().any())
print(employee.isna().sum())
employee.isna().sum().plot(kind="bar")
# Out:
#    EmpID FirstName LastName  StartDate ExitDate                    Title  \
# 0   3427     Uriah  Bridges 2019-09-20      NaT  Production Technician I
# 1   3428     Paula    Small 2023-02-11      NaT  Production Technician I
# 2   3429    Edward     Buck 2018-12-10      NaT       Area Sales Manager
#
#         Supervisor                      ADEmail BusinessUnit EmployeeStatus  \
# 0     Peter Oneill  uriah.bridges@bilearner.com         CCDR         Active
# 1  Renee Mccormick    paula.small@bilearner.com           EW         Active
# 2   Crystal Walker    edward.buck@bilearner.com           PL         Active
#
#    ...              Division                  DOB State  \
# 0  ...  Finance & Accounting  1969-07-10 00:00:00    MA
# 1  ...                Aerial           30-08-1965    MA
# 2  ...         General - Sga  1991-06-10 00:00:00    MA
#
#   JobFunctionDescription GenderCode LocationCode  RaceDesc MaritalDesc  \
# ...

# %%
print(employee.isna().any())
print(employee.isna().sum())
print(employee.isna().sum().plot(kind="bar"))
# Out:
# EmpID                         False
# FirstName                     False
# LastName                      False
# StartDate                     False
# ExitDate                       True
# Title                         False
# Supervisor                    False
# ADEmail                       False
# BusinessUnit                  False
# EmployeeStatus                False
# EmployeeType                  False
# PayZone                       False
# EmployeeClassificationType    False
# TerminationType               False
# TerminationDescription         True
# DepartmentType                False
# Division                      False
# DOB                           False
# State                         False
# JobFunctionDescription        False
# GenderCode                    False
# LocationCode                  False
# RaceDesc                      False
# MaritalDesc                   False
# Performance Score             False
# Current Employee Rating       False
# ...

# %%
employee.fillna(0)
# Out:
#       EmpID FirstName    LastName  StartDate             ExitDate  \
# 0      3427     Uriah     Bridges 2019-09-20                    0
# 1      3428     Paula       Small 2023-02-11                    0
# 2      3429    Edward        Buck 2018-12-10                    0
# 3      3430   Michael     Riordan 2021-06-21                    0
# 4      3431   Jasmine       Onque 2019-06-29                    0
# ...     ...       ...         ...        ...                  ...
# 2995   3422    Jakobe    Erickson 2022-06-22  2022-08-07 00:00:00
# 2996   3423    Adyson  Strickland 2020-12-28                    0
# 2997   3424   Annabel     Wilkins 2020-12-09  2022-08-04 00:00:00
# 2998   3425    Kendra       Braun 2019-05-28  2021-10-23 00:00:00
# 2999   3426     Chace        Kerr 2022-04-27                    0
#
#                         Title          Supervisor  \
# 0     Production Technician I        Peter Oneill
# 1     Production Technician I     Renee Mccormick
# ...

# %%
employee.fillna(0)
employee.fillna(0).isna().sum()
# Out:
# EmpID                         0
# FirstName                     0
# LastName                      0
# StartDate                     0
# ExitDate                      0
# Title                         0
# Supervisor                    0
# ADEmail                       0
# BusinessUnit                  0
# EmployeeStatus                0
# EmployeeType                  0
# PayZone                       0
# EmployeeClassificationType    0
# TerminationType               0
# TerminationDescription        0
# DepartmentType                0
# Division                      0
# DOB                           0
# State                         0
# JobFunctionDescription        0
# GenderCode                    0
# LocationCode                  0
# RaceDesc                      0
# MaritalDesc                   0
# Performance Score             0
# Current Employee Rating       0
# dtype: int64
